# %%
#for mathematical computation
import pandas as pd
import numpy as np
import scipy.stats as stats
import datetime

# %%
Summer_Pre_COVID_Births = pd.read_csv('../data/Pre COVID Birth(All States)/Summer_Pre_COVID_Births_(All States).csv')
Summer_Pre_COVID_Births
# Out:
#     Year  Year Code      Month  Month Code  Births
# 0   2018       2018    January           1  313843
# 1   2018       2018   February           2  283382
# 2   2018       2018      March           3  315072
# 3   2018       2018      April           4  297483
# 4   2018       2018        May           5  319692
# 5   2018       2018       June           6  313878
# 6   2018       2018       July           7  328033
# 7   2018       2018     August           8  343708
# 8   2018       2018  September           9  321926
# 9   2018       2018    October          10  325790
# 10  2018       2018   November          11  307743
# 11  2018       2018   December          12  309851
# 12  2019       2019    January           1  309887
# 13  2019       2019   February           2  279096
# 14  2019       2019      March           3  303313
# 15  2019       2019      April           4  298014
# 16  2019       2019        May           5  315426
# ...

# %%
Birth_months= Summer_Pre_COVID_Births.loc[(Summer_Pre_COVID_Births['Month']=='February')|(Summer_Pre_COVID_Births['Month']=='March')|(Summer_Pre_COVID_Births['Month']=='April')|(Summer_Pre_COVID_Births['Month']=='May')]

# %%
Birth_year_mean = round(Birth_months.groupby('Year').mean()).reset_index().drop(columns=['Year Code','Month Code'])
Birth_year_mean.loc[[0],['Year']]=2017
Birth_year_mean.loc[[1],['Year']]=2018
Birth_year_mean.loc[[2],['Year']]=2019
Birth_year_mean
# Out:
#    Year    Births
# 0  2017  303907.0
# 1  2018  298962.0
# 2  2019  293124.0

# %%
Feb = Birth.loc[(Birth['Year']==2018) & (Birth['Month']=='February')]

# %%
Feb['Births'].sum()
# Out:
# 283382

# %%
Birth
# Out:
#     Year  Year Code      Month  Month Code  Births
# 0   2018       2018    January           1  313843
# 1   2018       2018   February           2  283382
# 2   2018       2018      March           3  315072
# 3   2018       2018      April           4  297483
# 4   2018       2018        May           5  319692
# 5   2018       2018       June           6  313878
# 6   2018       2018       July           7  328033
# 7   2018       2018     August           8  343708
# 8   2018       2018  September           9  321926
# 9   2018       2018    October          10  325790
# 10  2018       2018   November          11  307743
# 11  2018       2018   December          12  309851
# 12  2019       2019    January           1  309887
# 13  2019       2019   February           2  279096
# 14  2019       2019      March           3  303313
# 15  2019       2019      April           4  298014
# 16  2019       2019        May           5  315426
# ...

# %%
Birth_months = Birth.loc[(Birth['Month']=='February')|(Birth['Month']=='March')|(Birth['Month']=='April')|(Birth['Month']=='May')]

# %%
Birth_months
# Out:
#     Year  Year Code     Month  Month Code  Births
# 1   2018       2018  February           2  283382
# 2   2018       2018     March           3  315072
# 3   2018       2018     April           4  297483
# 4   2018       2018       May           5  319692
# 13  2019       2019  February           2  279096
# 14  2019       2019     March           3  303313
# 15  2019       2019     April           4  298014
# 16  2019       2019       May           5  315426
# 25  2020       2020  February           2  281753
# 26  2020       2020     March           3  300718
# 27  2020       2020     April           4  289512
# 28  2020       2020       May           5  300515

# %%
Birth_months = Birth.loc[(Birth['Month']=='February')|(Birth['Month']=='March')|(Birth['Month']=='April')|(Birth['Month']=='May')]

# %%
Birth_months.groupby('Month')[['Births']].mean().reset_index()
# Out:
#       Month         Births
# 0     April  295003.000000
# 1  February  281410.333333
# 2     March  306367.666667
# 3       May  311877.666667

# %%
Birth_months['Births'].mean()
# Out:
# 5946.285947712418

# %%
Birth_months.dtypes
# Out:
# State         object
# State Code     int64
# Year           int64
# Year Code      int64
# Month         object
# Month Code     int64
# Births         int64
# dtype: object

# %%
Birth_months['Births'].mean()
# Out:
# 5946.285947712418

# %%
pd.read_csv('../data/Natality, 2007-2020 (4).csv')
# Out:
#         Month  Month Code    Year  Year Code   Births
# 0     January           1  2018.0     2018.0   313843
# 1     January           1  2019.0     2019.0   309887
# 2     January           1  2020.0     2020.0   303732
# 3       Total           1     NaN        NaN   927462
# 4    February           2  2018.0     2018.0   283382
# 5    February           2  2019.0     2019.0   279096
# 6    February           2  2020.0     2020.0   281753
# 7       Total           2     NaN        NaN   844231
# 8       March           3  2018.0     2018.0   315072
# 9       March           3  2019.0     2019.0   303313
# 10      March           3  2020.0     2020.0   300718
# 11      Total           3     NaN        NaN   919103
# 12      April           4  2018.0     2018.0   297483
# 13      April           4  2019.0     2019.0   298014
# 14      April           4  2020.0     2020.0   289512
# 15      Total           4     NaN        NaN   885009
# ...
